# %%
import osmnx as ox
import networkx as nx

# Descarga el grafo vial de una zona urbana
place = "Logroño, La Rioja, Spain"
graph = ox.graph_from_place(place, network_type="drive")

# Simplifica (elimina nodos redundantes como curvas sin intersección)
# graph = ox.simplify_graph(graph)

# Guarda como archivo .graphml si quieres reutilizarlo
ox.save_graphml(graph, filepath="../data/graph_data/logrono.graphml")

# %%
import osmnx as ox

# Define la zona
place = "Salamanca, Madrid, Spain"

# Descarga la red vial para coches
G = ox.graph_from_place(place, network_type="drive")

# Simplifica y plotea
ox.plot_graph(G, node_size=0, edge_color='gray')
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
ox.plot_graph(
    G,
    node_size=10,
    node_color='red',
    edge_color='gray',
    edge_linewidth=0.8,
    bgcolor='white'
)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
